# %% [markdown]
# # Basic Multiclass Neural Network Modifications and Their Effects
#
# ### This a set of tests to see how changing a simple multiclass neural network affects its accuracy, loss, and training time. The tests are based on an example in section 3.5 of Francois Chollet's book *Deep Learning with Python*

# %%
from keras import models, layers
from keras.datasets import reuters
from keras.utils.np_utils import to_categorical

import numpy as np

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# For the purpose of these tests, we will be using a dataset of Reuters newswires from 1986. We will check to see how many words in each review match a list of 10,000 words. We will then try to determine a correlation between the words used in a review and which of 46 categories the newswire belongs in. We will be assigning each newswire to only one category.

# %%
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)

number_of_examples = 7
example_number = 0

example_accuracies = np.zeros(number_of_examples)

# %% [markdown]
# The following function will take an array reviews and return a matrix that breaks down each review into a 10,000 element vector of ones and zeros depending on whether corresponding words were used in each review.

# %%
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

# %%
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
training_labels = to_categorical(train_labels)
testing_labels = to_categorical(test_labels)

# %% [markdown]
# To start with, let's set aside some of the training reviews to be used exclusively for testing the model's accuracy on fresh data during training.

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]

y_val = training_labels[:1000]
partial_y_train = training_labels[1000:]

# %% [markdown]
# The following function creates a basic feed forward neural network and returns a dictionary with information about the training and testing of the neural network. We will use this to test how changing things around affects training time and results.
#
# We're not going to go into too much detail about these neural networks' internal workings in this file, but one interesting thing to note is that the last layer uses a softmax activation function. This means that our output layer will be an array of probabilities that a newswire belongs in each category.

# %%
def make_train_and_test_model(input_epochs=9,
                              hidden_layers=2, 
                              nodes_per_layer=64):
    
    return_dict = dict()

    model = models.Sequential()
    model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
    
    for _ in range(hidden_layers - 1):
        model.add(layers.Dense(nodes_per_layer, activation='relu'))
    
    model.add(layers.Dense(46, activation='softmax'))

    model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

    return_dict['history'] = model.fit(partial_x_train, partial_y_train, epochs=input_epochs, batch_size=512, validation_data=(x_val, y_val))

    return_dict['results'] = model.evaluate(x_test, testing_labels)
    
    return return_dict

# %% [markdown]
# To get things running, we will start with a neural network with two hidden layers consisting of the following elements:

# %% [markdown]
# ### Example 1
# * number of epochs = 20
# * number of hidden layers = 2
# * nodes per hidden layer = 64

# %%
returned_dict = make_train_and_test_model(input_epochs=20)
# Out:
# WARNING:tensorflow:From C:\Users\joeyn\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\joeyn\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/20
# 7982/7982 [==============================] - 3s 355us/step - loss: 2.5317 - acc: 0.4959 - val_loss: 1.7193 - val_acc: 0.6120
# Epoch 2/20
# 7982/7982 [==============================] - 2s 222us/step - loss: 1.4441 - acc: 0.6883 - val_loss: 1.3450 - val_acc: 0.7070
# Epoch 3/20
# 7982/7982 [==============================] - 2s 228us/step - loss: 1.0940 - acc: 0.7656 - val_loss: 1.1706 - val_acc: 0.7440
# Epoch 4/20
# 7982/7982 [==============================] - 2s 223us/step - loss: 0.8686 - acc: 0.8163 - val_loss: 1.0806 - val_acc: 0.7570
# Epoch 5/20
# 7982/7982 [==============================] - 2s 225us/step - loss: 0.7022 - acc: 0.8478 - val_loss: 0.9840 - val_acc: 0.7840
# Epoch 6/20
# 7982/7982 [==============================] - 2s 228us/step - loss: 0.5657 - acc: 0.8800 - val_loss: 0.9413 - val_acc: 0.8040
# Epoch 7/20
# 7982/7982 [==============================] - 2s 224us/step - loss: 0.4573 - acc: 0.9045 - val_loss: 0.9086 - val_acc: 0.8030
# Epoch 8/20
# 7982/7982 [==============================] - 2s 228us/step - loss: 0.3687 - acc: 0.9237 - val_loss: 0.9369 - val_acc: 0.7900
# Epoch 9/20
# 7982/7982 [==============================] - 2s 225us/step - loss: 0.3029 - acc: 0.9315 - val_loss: 0.8919 - val_acc: 0.8070
# Epoch 10/20
# 7982/7982 [==============================] - 2s 230us/step - loss: 0.2540 - acc: 0.9420 - val_loss: 0.9054 - val_acc: 0.8130
# Epoch 11/20
# 7982/7982 [==============================] - 2s 224us/step - loss: 0.2185 - acc: 0.9468 - val_loss: 0.9171 - val_acc: 0.8130
# Epoch 12/20
# 7982/7982 [==============================] - 2s 221us/step - loss: 0.1872 - acc: 0.9511 - val_loss: 0.9072 - val_acc: 0.8130
# Epoch 13/20
# 7982/7982 [==============================] - 2s 227us/step - loss: 0.1699 - acc: 0.9525 - val_loss: 0.9361 - val_acc: 0.8060
# Epoch 14/20
# 7982/7982 [==============================] - 2s 228us/step - loss: 0.1539 - acc: 0.9553 - val_loss: 0.9672 - val_acc: 0.8080
# Epoch 15/20
# 7982/7982 [==============================] - 2s 230us/step - loss: 0.1391 - acc: 0.9558 - val_loss: 0.9702 - val_acc: 0.8160
# Epoch 16/20
# 7982/7982 [==============================] - 2s 222us/step - loss: 0.1315 - acc: 0.9562 - val_loss: 1.0243 - val_acc: 0.8040
# Epoch 17/20
# 7982/7982 [==============================] - 2s 228us/step - loss: 0.1219 - acc: 0.9580 - val_loss: 1.0243 - val_acc: 0.7960
# Epoch 18/20
# 7982/7982 [==============================] - 2s 227us/step - loss: 0.1197 - acc: 0.9580 - val_loss: 1.0445 - val_acc: 0.8060
# Epoch 19/20
# 7982/7982 [==============================] - 2s 226us/step - loss: 0.1138 - acc: 0.9598 - val_loss: 1.1024 - val_acc: 0.7960
# Epoch 20/20
# 7982/7982 [==============================] - 2s 233us/step - loss: 0.1113 - acc: 0.9595 - val_loss: 1.0709 - val_acc: 0.8020
# 2246/2246 [==============================] - 1s 261us/step

# %% [markdown]
# The following function will plot training loss and validation loss after each epoch.

# %%
def plot_loss(input_dict):
    loss = input_dict['history'].history['loss']
    val_loss = input_dict['history'].history['val_loss']

    epochs = range(1, len(loss) + 1)

    plt.clf()

    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'co', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# %% [markdown]
# This function will plot training accuracy and validation accuracy after each epoch.

# %%
def plot_accuracy(input_dict):
    acc = input_dict['history'].history['acc']
    val_acc = input_dict['history'].history['val_acc']

    epochs = range(1, len(acc) + 1)

    plt.clf()

    plt.plot(epochs, acc, 'ro', label='Training acc')
    plt.plot(epochs, val_acc, 'mo', label='Validation acc')
    plt.title('Training and validation accuracys')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()

# %%
plot_loss(returned_dict)
plot_accuracy(returned_dict)

print("Accuracy: " + str(returned_dict['results'][1]))
print("Loss: " + str(returned_dict['results'][0]))

example_accuracies[example_number] = returned_dict['results'][1]
example_number += 1
# Out:
# Accuracy: 0.7778272484947504
# Loss: 1.2129871125531217

# %% [markdown]
# As we can see, validation training and validation loss do not seem to improve after nine epochs, so we'll stop training the rest of our neural networks after nine epochs. Below is what that looks like.

# %%
returned_dict = make_train_and_test_model()
plot_loss(returned_dict)
plot_accuracy(returned_dict)

print("Accuracy: " + str(returned_dict['results'][1]))
print("Loss: " + str(returned_dict['results'][0]))

example_accuracies[example_number] = returned_dict['results'][1]
example_number += 1
# Out:
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/9
# 7982/7982 [==============================] - 3s 373us/step - loss: 2.7467 - acc: 0.5361 - val_loss: 1.7526 - val_acc: 0.6580
# Epoch 2/9
# 7982/7982 [==============================] - 2s 238us/step - loss: 1.4174 - acc: 0.7137 - val_loss: 1.2962 - val_acc: 0.7170
# Epoch 3/9
# 7982/7982 [==============================] - 2s 246us/step - loss: 1.0402 - acc: 0.7767 - val_loss: 1.1316 - val_acc: 0.7510
# Epoch 4/9
# 7982/7982 [==============================] - 2s 228us/step - loss: 0.8128 - acc: 0.8299 - val_loss: 1.0262 - val_acc: 0.7810
# Epoch 5/9
# 7982/7982 [==============================] - 2s 231us/step - loss: 0.6458 - acc: 0.8690 - val_loss: 0.9572 - val_acc: 0.8080
# Epoch 6/9
# 7982/7982 [==============================] - 2s 233us/step - loss: 0.5156 - acc: 0.8946 - val_loss: 0.9139 - val_acc: 0.8050
# Epoch 7/9
# 7982/7982 [==============================] - 2s 232us/step - loss: 0.4149 - acc: 0.9153 - val_loss: 0.8722 - val_acc: 0.8190
# Epoch 8/9
# 7982/7982 [==============================] - 2s 240us/step - loss: 0.3382 - acc: 0.9300 - val_loss: 0.9008 - val_acc: 0.8110
# Epoch 9/9
# 7982/7982 [==============================] - 2s 233us/step - loss: 0.2821 - acc: 0.9387 - val_loss: 0.8768 - val_acc: 0.8270
# 2246/2246 [==============================] - 1s 251us/step
# Accuracy: 0.792520035618878
# Loss: 0.9760002709878733

# %% [markdown]
# This seems like a good starting point to modify our neural network from. We used 64 nodes per hidden layer to start with. Let's see what happens when we ony use four hidden nodes on one of those layers.

# %%
returned_dict = make_train_and_test_model(nodes_per_layer=4)
plot_loss(returned_dict)
plot_accuracy(returned_dict)
print("Accuracy: " + str(returned_dict['results'][1]))
print("Loss: " + str(returned_dict['results'][0]))

example_accuracies[example_number] = returned_dict['results'][1]
example_number += 1
# Out:
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/9
# 7982/7982 [==============================] - 3s 316us/step - loss: 3.5511 - acc: 0.1932 - val_loss: 3.3089 - val_acc: 0.2380
# Epoch 2/9
# 7982/7982 [==============================] - 2s 225us/step - loss: 3.1232 - acc: 0.2607 - val_loss: 2.9537 - val_acc: 0.2570
# Epoch 3/9
# 7982/7982 [==============================] - 2s 232us/step - loss: 2.7383 - acc: 0.2793 - val_loss: 2.6199 - val_acc: 0.2830
# Epoch 4/9
# 7982/7982 [==============================] - 2s 221us/step - loss: 2.3880 - acc: 0.3073 - val_loss: 2.3091 - val_acc: 0.3980
# Epoch 5/9
# 7982/7982 [==============================] - 2s 226us/step - loss: 2.0440 - acc: 0.5788 - val_loss: 1.9860 - val_acc: 0.6060
# Epoch 6/9
# 7982/7982 [==============================] - 2s 233us/step - loss: 1.7278 - acc: 0.6413 - val_loss: 1.7580 - val_acc: 0.6160
# Epoch 7/9
# 7982/7982 [==============================] - 2s 224us/step - loss: 1.5081 - acc: 0.6546 - val_loss: 1.6225 - val_acc: 0.6260
# Epoch 8/9
# 7982/7982 [==============================] - 2s 227us/step - loss: 1.3708 - acc: 0.6639 - val_loss: 1.5461 - val_acc: 0.6370
# Epoch 9/9
# 7982/7982 [==============================] - 2s 226us/step - loss: 1.2707 - acc: 0.6719 - val_loss: 1.5109 - val_acc: 0.6380
# 2246/2246 [==============================] - 0s 217us/step
# Accuracy: 0.6300089047195013
# Loss: 1.5668256940952074

# %% [markdown]
# It is evident from our plots that reducing the nodes in one of our hidden layers from 64 to four has caused our validation accuracy to reach its optimal value sooner. However, the test accuracy of the 64 node model was 79 percent while the test accuracy from our four node model only reached 63 percent. This is because the model has a bottleneck. 10,000 input nodes are funneled down to four nodes, which then must reach 46 output nodes. Four dimensions are insufficient to effectively describe the 46 dimension outputs, even after the network manipulates the output from the four node layer The model's accuracy suffers as a result.
#
# Let's try to meet in the middle. This next model will have a hidden layer comprised of 32 nodes.

# %%
returned_dict = make_train_and_test_model(nodes_per_layer=32)
plot_loss(returned_dict)
plot_accuracy(returned_dict)

print("Accuracy: " + str(returned_dict['results'][1]))
print("Loss: " + str(returned_dict['results'][0]))

example_accuracies[example_number] = returned_dict['results'][1]
example_number += 1
# Out:
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/9
# 7982/7982 [==============================] - 3s 334us/step - loss: 2.7287 - acc: 0.5261 - val_loss: 1.8547 - val_acc: 0.6420
# Epoch 2/9
# 7982/7982 [==============================] - 2s 227us/step - loss: 1.5008 - acc: 0.7042 - val_loss: 1.3501 - val_acc: 0.7110
# Epoch 3/9
# 7982/7982 [==============================] - 2s 223us/step - loss: 1.0963 - acc: 0.7765 - val_loss: 1.1838 - val_acc: 0.7380
# Epoch 4/9
# 7982/7982 [==============================] - 2s 239us/step - loss: 0.8716 - acc: 0.8201 - val_loss: 1.0536 - val_acc: 0.7880
# Epoch 5/9
# 7982/7982 [==============================] - 2s 229us/step - loss: 0.7007 - acc: 0.8574 - val_loss: 1.0138 - val_acc: 0.7990
# Epoch 6/9
# 7982/7982 [==============================] - 2s 225us/step - loss: 0.5701 - acc: 0.8864 - val_loss: 0.9622 - val_acc: 0.7990
# Epoch 7/9
# 7982/7982 [==============================] - 2s 222us/step - loss: 0.4669 - acc: 0.9065 - val_loss: 0.9470 - val_acc: 0.8030
# Epoch 8/9
# 7982/7982 [==============================] - 2s 230us/step - loss: 0.3855 - acc: 0.9191 - val_loss: 0.9167 - val_acc: 0.8160
# Epoch 9/9
# 7982/7982 [==============================] - 2s 227us/step - loss: 0.3220 - acc: 0.9334 - val_loss: 0.9264 - val_acc: 0.8080
# 2246/2246 [==============================] - 1s 247us/step
# Accuracy: 0.7733748887175443
# Loss: 0.9987261840942601

# %% [markdown]
# It did pretty well, 77 percent compared to the original 79 percent. However, a two percent drop in accuracy is still pretty bad. For this next eaxmple, we are going to double the amount of nodes in a hidden layer from our original model, from 64 nodes in a hidden layer to 128 nodes.

# %%
returned_dict = make_train_and_test_model(nodes_per_layer=128)
plot_loss(returned_dict)
plot_accuracy(returned_dict)

print("Accuracy: " + str(returned_dict['results'][1]))
print("Loss: " + str(returned_dict['results'][0]))

example_accuracies[example_number] = returned_dict['results'][1]
example_number += 1
# Out:
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/9
# 7982/7982 [==============================] - 3s 322us/step - loss: 2.3967 - acc: 0.5460 - val_loss: 1.5462 - val_acc: 0.6560
# Epoch 2/9
# 7982/7982 [==============================] - 2s 224us/step - loss: 1.2881 - acc: 0.7184 - val_loss: 1.2250 - val_acc: 0.7270
# Epoch 3/9
# 7982/7982 [==============================] - 2s 234us/step - loss: 0.9695 - acc: 0.7846 - val_loss: 1.0775 - val_acc: 0.7590
# Epoch 4/9
# 7982/7982 [==============================] - 2s 236us/step - loss: 0.7466 - acc: 0.8348 - val_loss: 0.9992 - val_acc: 0.7830
# Epoch 5/9
# 7982/7982 [==============================] - 2s 224us/step - loss: 0.5834 - acc: 0.8750 - val_loss: 0.9472 - val_acc: 0.7930
# Epoch 6/9
# 7982/7982 [==============================] - 2s 224us/step - loss: 0.4540 - acc: 0.9049 - val_loss: 0.9014 - val_acc: 0.8070
# Epoch 7/9
# 7982/7982 [==============================] - 2s 226us/step - loss: 0.3614 - acc: 0.9231 - val_loss: 0.9165 - val_acc: 0.7990
# Epoch 8/9
# 7982/7982 [==============================] - 2s 221us/step - loss: 0.2884 - acc: 0.9387 - val_loss: 0.9009 - val_acc: 0.8060
# Epoch 9/9
# 7982/7982 [==============================] - 2s 225us/step - loss: 0.2414 - acc: 0.9448 - val_loss: 0.9361 - val_acc: 0.8090
# 2246/2246 [==============================] - 1s 230us/step
# Accuracy: 0.7911843276406014
# Loss: 1.0017086750465318

# %% [markdown]
# Here we can see that the training for the 128 nodes model looks very similar to the training for 64 nodes nodes model. They both ended with 79 percent accuracy, but because there were more computations needed to train the 128 node layer, it took more time to train. The model is not over fit, but the excessive nodes with no improved accuracy makes this an in efficient model.
#
# For this next model, we will only use one hidden layer. We know that it will take less time to train, but let's see if it is less accurate.

# %%
returned_dict = make_train_and_test_model(hidden_layers=1)
plot_loss(returned_dict)
plot_accuracy(returned_dict)

print("Accuracy: " + str(returned_dict['results'][1]))
print("Loss: " + str(returned_dict['results'][0]))

example_accuracies[example_number] = returned_dict['results'][1]
example_number += 1
# Out:
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/9
# 7982/7982 [==============================] - 3s 320us/step - loss: 2.5922 - acc: 0.5753 - val_loss: 1.8120 - val_acc: 0.6630
# Epoch 2/9
# 7982/7982 [==============================] - 2s 226us/step - loss: 1.4607 - acc: 0.7311 - val_loss: 1.3365 - val_acc: 0.7300
# Epoch 3/9
# 7982/7982 [==============================] - 2s 228us/step - loss: 1.0621 - acc: 0.7907 - val_loss: 1.1207 - val_acc: 0.7630
# Epoch 4/9
# 7982/7982 [==============================] - 2s 221us/step - loss: 0.8252 - acc: 0.8322 - val_loss: 1.0015 - val_acc: 0.8040
# Epoch 5/9
# 7982/7982 [==============================] - 2s 226us/step - loss: 0.6621 - acc: 0.8715 - val_loss: 0.9334 - val_acc: 0.8030
# Epoch 6/9
# 7982/7982 [==============================] - 2s 219us/step - loss: 0.5415 - acc: 0.8940 - val_loss: 0.8774 - val_acc: 0.8180
# Epoch 7/9
# 7982/7982 [==============================] - 2s 220us/step - loss: 0.4470 - acc: 0.9118 - val_loss: 0.8485 - val_acc: 0.8200
# Epoch 8/9
# 7982/7982 [==============================] - 2s 218us/step - loss: 0.3711 - acc: 0.9257 - val_loss: 0.8322 - val_acc: 0.8210
# Epoch 9/9
# 7982/7982 [==============================] - 2s 219us/step - loss: 0.3120 - acc: 0.9364 - val_loss: 0.8233 - val_acc: 0.8260
# 2246/2246 [==============================] - 0s 218us/step
# Accuracy: 0.790739091745149
# Loss: 0.9217490491756667

# %% [markdown]
# It appears that our one-hidden-layer model has the same accuracy as our original model with two hidden layers. This means that we can save time and computing power by using only one layer, becuase we have such a simple situation.
#
# This next example will test to see if using three hidden layers improves our models accuracy.

# %%
returned_dict = make_train_and_test_model(hidden_layers=3)
plot_loss(returned_dict)
plot_accuracy(returned_dict)

print("Accuracy: " + str(returned_dict['results'][1]))
print("Loss: " + str(returned_dict['results'][0]))

example_accuracies[example_number] = returned_dict['results'][1]
example_number += 1
# Out:
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/9
# 7982/7982 [==============================] - 3s 361us/step - loss: 2.7706 - acc: 0.4612 - val_loss: 1.7938 - val_acc: 0.5980
# Epoch 2/9
# 7982/7982 [==============================] - 2s 238us/step - loss: 1.5094 - acc: 0.6730 - val_loss: 1.4135 - val_acc: 0.6750
# Epoch 3/9
# 7982/7982 [==============================] - 2s 224us/step - loss: 1.1437 - acc: 0.7413 - val_loss: 1.2038 - val_acc: 0.7330
# Epoch 4/9
# 7982/7982 [==============================] - 2s 224us/step - loss: 0.9161 - acc: 0.7923 - val_loss: 1.1013 - val_acc: 0.7680
# Epoch 5/9
# 7982/7982 [==============================] - 2s 227us/step - loss: 0.7497 - acc: 0.8316 - val_loss: 1.0190 - val_acc: 0.7890
# Epoch 6/9
# 7982/7982 [==============================] - 2s 223us/step - loss: 0.5945 - acc: 0.8690 - val_loss: 0.9719 - val_acc: 0.7990
# Epoch 7/9
# 7982/7982 [==============================] - 2s 220us/step - loss: 0.4856 - acc: 0.8935 - val_loss: 0.9688 - val_acc: 0.7970
# Epoch 8/9
# 7982/7982 [==============================] - 2s 224us/step - loss: 0.3790 - acc: 0.9158 - val_loss: 0.9572 - val_acc: 0.8040
# Epoch 9/9
# 7982/7982 [==============================] - 2s 222us/step - loss: 0.3304 - acc: 0.9287 - val_loss: 0.9786 - val_acc: 0.7990
# 2246/2246 [==============================] - 1s 227us/step
# Accuracy: 0.7707034728936818
# Loss: 1.0723147224551954

# %% [markdown]
# It looks like having three hidden layers resulted in some overfitting, which dropped its accuracy.
#
# Finally, let's compare our models' testing accuracies.

# %%
example_numbers = range(1, number_of_examples + 1)

plt.clf()

plt.plot(example_numbers, example_accuracies, 'bo')
plt.title('Example accuracies')
plt.xlabel('Eample order')
plt.ylabel('Accuracy')

plt.show()

# %% [markdown]
# We've covered the details above, but this plot emphasizes that our changes resulted in mostly minor differences in accuracies, with the exception of our bottleneck case.
#
# The main takeaway from this is that getting the most from our neural networks in the most efficient way can require nuance, but some things are just really wrong.
